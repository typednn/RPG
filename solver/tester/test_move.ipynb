# %%
# %load_ext autoreload
# %autoreload 2

# %%
from cpt.solver.cut import sample_u_maze
from cpt.solver import make_env
from cpt.solver.pose_sampler import sample_gripper_pose

env = make_env('move')
env.reset()
# Out:
# E: 5000.0
# gravity: (0., -1., 0.)
# grid_size: (1., 1., 1.)
# ground_friction: 5.0
# max_steps: 1024
# n_particles: 20000
# nu: 0.2
# yield_stress: 100.0
# LOADING....
# Loaded with 0.00034618377685546875 secs.
# GPU 0/1 memory: free=6.727, total=10.917
# init renderer
# task not specified
# {'pointcloud': tensor([[0.5178, 0.2074, 0.5970,  ..., 0.0000, 0.0000, 0.0000],
#          [0.4805, 0.2462, 0.5820,  ..., 0.0000, 0.0000, 0.0000],
#          [0.4556, 0.1962, 0.5297,  ..., 0.0000, 0.0000, 0.0000],
#          ...,
#          [0.2600, 0.1700, 0.4500,  ..., 0.0000, 0.0000, 1.0000],
#          [0.2600, 0.2000, 0.6000,  ..., 0.0000, 0.0000, 1.0000],
#          [0.2400, 0.1400, 0.4000,  ..., 0.0000, 0.0000, 1.0000]],
#         device='cuda:0'),
#  'agent': tensor([0.2500, 0.1000, 0.5000, 1.0000, 0.0000, 0.0000, 0.0000, 0.3000, 0.1000,
#          0.5000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000], device='cuda:0'),
#  'mask': 1}

# %%
state, goal = sample_u_maze(env)
env.reset_state_goal(state, goal)
# print(env.get_state()['tools'])
env.render('plt')
# Out:
# array([[[ 76,  98, 116],
#         [ 76,  98, 116],
#         [ 76,  98, 116],
#         ...,
#         [ 77,  99, 117],
#         [ 76,  98, 116],
#         [ 76,  99, 117]],
#
#        [[ 76,  98, 116],
#         [ 76,  98, 117],
#         [ 76,  98, 117],
#         ...,
#         [ 76,  99, 117],
#         [ 76,  99, 117],
#         [ 76,  98, 116]],
#
#        [[ 76,  98, 116],
#         [ 76,  98, 116],
#         [ 77,  99, 118],
#         ...,
#         [ 76,  99, 117],
#         [ 76,  98, 117],
#         [ 76,  98, 116]],
#
#        ...,
#
#        [[ 76,  98, 117],
#         [ 76,  99, 117],
#         [ 64,  83,  98],
#         ...,
#         [ 77,  99, 117],
#         [ 76,  99, 117],
#         [ 76,  98, 117]],
#
#        [[ 76,  98, 117],
#         [ 76,  98, 116],
#         [ 76,  99, 117],
#         ...,
#         [ 76,  99, 117],
#         [ 76,  98, 116],
#         [ 76,  99, 117]],
#
#        [[ 76,  98, 116],
#         [ 76,  98, 116],
#         [ 76,  99, 117],
# ...
