# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = '0'

from llm.tiny import Scene
from envs import MultiToolEnv
from envs.test_utils import init_scene

env = MultiToolEnv(sim_cfg=dict(max_steps=100))
init_scene(env, 0)
# Out:
# using device None
# GPU 0/1 memory: free=9.086, total=10.917
# init renderer
# GPU 0/1 memory: free=8.637, total=10.917

# %%
env.render('plt')

# %%
env.renderer.lookat((0., 0., 0), 0.3, 0.5)
env.render('plt')
img = env.renderer.render(env.simulator, env.simulator.states[0])
print(img.shape)

import matplotlib.pyplot as plt

plt.imshow(img[..., -1])
# Out:
# (512, 512, 4)
